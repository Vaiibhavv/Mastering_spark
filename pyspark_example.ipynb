# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder.appName("app1").master("local[*]").getOrCreate()

# df=spark.read.format("csv") \
#    .option("inferSchema",True) \
#     .option("header",True) \
#     .load("orders.csv")

# df.show(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 from pyspark.sql import SparkSession
#       2
# ----> 3 spark=SparkSession.builder.appName("app1").master("local[*]").getOrCreate()
#       4
#       5 # df=spark.read.format("csv") \
#       6 #    .option("inferSchema",True) \
#
# File d:\Codebase\Pyspark\pyspark_venv\Lib\site-packages\pyspark\sql\session.py:562, in SparkSession.Builder.getOrCreate(self)
#     559     sc = SparkContext.getOrCreate(sparkConf)
#     560     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     561     # by all sessions.
# --> 562     session = SparkSession(sc, options=self._options)
#     563 else:
#     564     module = SparkSession._get_j_spark_session_module(session._jvm)
#
# File d:\Codebase\Pyspark\pyspark_venv\Lib\site-packages\pyspark\sql\session.py:660, in SparkSession.__init__(self, sparkContext, jsparkSession, options)
#     656 jSparkSessionModule = SparkSession._get_j_spark_session_module(self._jvm)
#     658 if jsparkSession is None:
#     659     if (
# --> 660         jSparkSessionClass.getDefaultSession().isDefined()
#     661         and not jSparkSessionClass.getDefaultSession().get().sparkContext().isStopped()
#     662     ):
#     663         jsparkSession = jSparkSessionClass.getDefaultSession().get()
#     664         jSparkSessionModule.applyModifiableSettings(jsparkSession, options)
#
# TypeError: 'JavaPackage' object is not callable

# %%
import pyspark

print(pyspark.__version__)
